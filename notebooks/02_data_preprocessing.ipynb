# %% [markdown]
# # NTCF - Data Preprocessing
#
# ## Objective
# This notebook demonstrates the data preprocessing pipeline for the Network Threat Cognition Framework (NTCF).

# %%
import pandas as pd

from ml.preprocessing.data_loader import load_dataset
from ml.preprocessing.cleaner import (
    remove_missing_values,
    remove_duplicates,
    handle_invalid_values,
    standardize_text,
    split_features_target,
    save_processed_data,
)
from ml.preprocessing.preprocessing_pipeline import preprocess_dataset

# %% [markdown]
# ## Step 1: Load the Raw Dataset

# %%
df = load_dataset()
print("Dataset loaded successfully.")
# Out:
# Dataset loaded successfully.

# %%
df.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# 1                    0.60                         0.88
# ...

# %% [markdown]
# ## Step 2: Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 125973 entries, 0 to 125972
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     125973 non-null  int64
#  1   protocol_type                125973 non-null  str
#  2   service                      125973 non-null  str
#  3   flag                         125973 non-null  str
#  4   src_bytes                    125973 non-null  int64
#  5   dst_bytes                    125973 non-null  int64
#  6   land                         125973 non-null  int64
#  7   wrong_fragment               125973 non-null  int64
#  8   urgent                       125973 non-null  int64
#  9   hot                          125973 non-null  int64
#  10  num_failed_logins            125973 non-null  int64
#  11  logged_in                    125973 non-null  int64
#  12  num_compromised              125973 non-null  int64
# ...

# %%
print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (125973, 43)

# %% [markdown]
# ## Step 3: Check Missing Values

# %%
df.isnull().sum()
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# ...

# %% [markdown]
# ## Step 4: Check Duplicate Records

# %%
duplicates = df.duplicated().sum()
print("Number of duplicate records:", duplicates)
# Out:
# Number of duplicate records: 0

# %% [markdown]
# ## Step 5: Run the Data Cleaning Module

# %%
cleaned_df = remove_missing_values(df)
print("Data cleaning completed successfully.")
# Out:
# Data cleaning completed successfully.

# %%
cleaned_df.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# 1                    0.60                         0.88
# ...

# %% [markdown]
# ## Step 6: Verify the Cleaned Dataset

# %%
print("Cleaned Dataset Shape:", cleaned_df.shape)
# Out:
# Cleaned Dataset Shape: (125973, 43)

# %%
print("Missing Values After Cleaning")
cleaned_df.isnull().sum()
# Out:
# Missing Values After Cleaning
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# ...

# %%
print("Duplicate Records After Cleaning:")
print(cleaned_df.duplicated().sum())
# Out:
# Duplicate Records After Cleaning:
# 0

# %% [markdown]
# ## Step 7: Separate Features and Target Variable

# %%
X, y = split_features_target(cleaned_df)

# %%
print("Feature Matrix Shape:", X.shape)
print("Target Vector Shape:", y.shape)
# Out:
# Feature Matrix Shape: (125973, 42)
# Target Vector Shape: (125973,)

# %% [markdown]
# ## Step 8: Execute the Complete Preprocessing Pipeline

# %%
X, y, cleaned_df = preprocess_dataset()
print("Pipeline executed successfully.")
# Out:
# Pipeline executed successfully.

# %%
print("Features Shape:", X.shape)
print("Target Shape:", y.shape)
print("Cleaned Dataset Shape:", cleaned_df.shape)
# Out:
# Features Shape: (125973, 42)
# Target Shape: (125973,)
# Cleaned Dataset Shape: (125973, 43)

# %% [markdown]
# ## Step 9: Summary
#
# - Loads the raw NSL-KDD dataset
# - Validates the dataset path
# - Handles missing values
# - Removes duplicate records
# - Handles invalid values
# - Handles inconsistent values
# - Separates features and target labels
# - Preserves the original dataset in `data/raw/`.

# %% [markdown]
# # Conclusion
# The preprocessing pipeline has been successfully demonstrated and verified.
